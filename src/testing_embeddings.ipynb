# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files(list_datasets[2]["ref"])
# Out:
# Dataset URL: https://www.kaggle.com/datasets/bricevergnou/spotify-recommendation

# %%
import os
import zipfile

import pandas as pd


def get_kaggle_dataset(keyword):
    # List datasets based on the keyword
    list_datasets = api.datasets_list(search=keyword)
    
    if not list_datasets:
        raise ValueError(f"No datasets found for keyword: {keyword}")
    
    # Take the first dataset
    dataset_ref = list_datasets[0]["ref"]
    
    # Extract the dataset name from the ref
    dataset_name = dataset_ref.split("/")[-1]
    
    # Download the dataset
    api.dataset_download_files(dataset_ref)
    
    # Create a directory with the same name as the dataset
    os.makedirs(dataset_name, exist_ok=True)
    
    # Unzip the dataset
    with zipfile.ZipFile(f"{dataset_name}.zip", "r") as zip_ref:
        zip_ref.extractall(dataset_name)
    
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(f"{dataset_name}/data.csv")
    
    return df

# Example usage:
# df = get_kaggle_dataset("spotify")
# print(df.head())
# Out:
# spotify-recommendation
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.803  0.6240    7    -6.764     0       0.0477         0.451
# 1         0.762  0.7030   10    -7.951     0       0.3060         0.206
# 2         0.261  0.0149    1   -27.528     1       0.0419         0.992
# 3         0.722  0.7360    3    -6.994     0       0.0585         0.431
# 4         0.787  0.5720    1    -7.516     1       0.2220         0.145
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.000734    0.1000   0.6280   95.968       304524               4
# 1          0.000000    0.0912   0.5190  151.329       247178               4
# 2          0.897000    0.1020   0.0382   75.296       286987               4
# 3          0.000001    0.1230   0.5820   89.860       208920               4
# 4          0.000000    0.0753   0.6470  155.117       179413               4
#
#    liked
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1

# %%
import openai
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def generate_dataset_embedding(dataset_info):
    # Combine relevant information into a single string
    text = f"{dataset_info['title']} {dataset_info['subtitle']} {dataset_info['description']} "
    text += f"Tags: {', '.join([tag['name'] for tag in dataset_info['tags']])}"
    
    # Generate embedding using OpenAI API
    response = openai.Embedding.create(
        input=text,
        model="text-embedding-ada-002"
    )
    return response['data'][0]['embedding']

def build_dataset_embeddings(api, num_datasets=100):
    embeddings = []
    dataset_info = []
    
    for page in range(1, 501):  # Iterate through 500 pages
        datasets = api.datasets_list(page=page)
        
        for dataset in datasets:
            embedding = generate_dataset_embedding(dataset)
            embeddings.append(embedding)
            dataset_info.append({
                'ref': dataset['ref'],
                'title': dataset['title'],
                'subtitle': dataset['subtitle'],
                'url': dataset['url'],
                'creatorName': dataset['creatorName'],
                'tags': [tag['name'] for tag in dataset['tags']]
            })
            
            if len(embeddings) >= num_datasets:
                return embeddings, dataset_info
    
    return embeddings, dataset_info

def find_similar_dataset(query, embeddings, dataset_info):
    # Generate embedding for the query
    query_embedding = openai.Embedding.create(
        input=query,
        model="text-embedding-ada-002"
    )['data'][0]['embedding']
    
    # Calculate cosine similarity
    similarities = cosine_similarity([query_embedding], embeddings)[0]
    
    # Find the index of the most similar dataset
    most_similar_index = np.argmax(similarities)
    
    return dataset_info[most_similar_index]

# %% [markdown]
# ## saving the embeddings

# %%
from openai import OpenAI
from typing import Dict, List
import faiss
import pickle
from kaggle.api.kaggle_api_extended import KaggleApi
import os
import numpy as np
api = KaggleApi()
api.authenticate()

client = OpenAI()


def get_embedding(text: str) -> List[float]:
    """
    Get the embedding for the given text.
    """
    response = client.embeddings.create(
        input=text,
        model="text-embedding-3-small"
    )
    return response.data[0].embedding

def generate_dataset_embedding(dataset_info):
    text = f"{dataset_info['title']} {dataset_info['subtitle']} {dataset_info['description']} "
    text += f"Tags: {', '.join([tag['name'] for tag in dataset_info['tags']])}"
    
    return get_embedding(text)

def build_and_save_embeddings(api: KaggleApi, save_path: str = 'kaggle_embeddings', start_page: int = 1):
    dataset_info = []
    total_datasets = 0

    print("Starting to build and save embeddings...")

    # Load existing index and dataset info if they exist
    if os.path.exists(f'{save_path}.index') and os.path.exists(f'{save_path}_info.pkl'):
        print("Loading existing index and dataset info...")
        index = faiss.read_index(f'{save_path}.index')
        with open(f'{save_path}_info.pkl', 'rb') as f:
            dataset_info = pickle.load(f)
        total_datasets = len(dataset_info)
        print(f"Loaded {total_datasets} existing datasets.")
    else:
        # Create a new index
        sample_embedding = generate_dataset_embedding(api.datasets_list(page=1)[0])
        dimension = len(sample_embedding)
        index = faiss.IndexFlatL2(dimension)
        print(f"Created new FAISS index with dimension {dimension}")

    for page in range(start_page, 501):  # Process 500 pages
        print(f"Processing page {page} of 500...")
        datasets = api.datasets_list(page=page)
        
        page_embeddings = []
        page_info = []
        
        for dataset in datasets:
            embedding = generate_dataset_embedding(dataset)
            page_embeddings.append(embedding)
            page_info.append({
                'ref': dataset['ref'],
                'title': dataset['title'],
                'subtitle': dataset['subtitle'],
                'url': dataset['url'],
                'description': dataset['description'],
                'tags': [tag['name'] for tag in dataset['tags']]
            })
        
        # Add embeddings to the index
        embeddings_array = np.array(page_embeddings).astype('float32')
        index.add(embeddings_array)
        
        # Update dataset info
        dataset_info.extend(page_info)
        total_datasets += len(page_info)
        
        print(f"Added {len(page_info)} embeddings to the index. Total datasets processed: {total_datasets}")
        
        # Save progress after each page
        print(f"Saving progress...")
        faiss.write_index(index, f'{save_path}.index')
        with open(f'{save_path}_info.pkl', 'wb') as f:
            pickle.dump(dataset_info, f)

    print(f"Finished processing {total_datasets} datasets.")

# Usage: 
build_and_save_embeddings(api)
# To resume from a specific page:
# build_and_save_embeddings(api, start_page=last_processed_page + 1)
# Out:
# Starting to build and save embeddings...
# Created new FAISS index with dimension 1536
# Processing page 1 of 500...
# Added 20 embeddings to the index. Total datasets processed: 20
# Saving progress...
# Processing page 2 of 500...
# Added 20 embeddings to the index. Total datasets processed: 40
# Saving progress...
# Processing page 3 of 500...
# Added 20 embeddings to the index. Total datasets processed: 60
# Saving progress...
# Processing page 4 of 500...
# Added 20 embeddings to the index. Total datasets processed: 80
# Saving progress...
# Processing page 5 of 500...
# Added 20 embeddings to the index. Total datasets processed: 100
# Saving progress...
# Processing page 6 of 500...
# Added 19 embeddings to the index. Total datasets processed: 119
# Saving progress...
# Processing page 7 of 500...
# Added 19 embeddings to the index. Total datasets processed: 138
# Saving progress...
# Processing page 8 of 500...
# Added 19 embeddings to the index. Total datasets processed: 157
# Saving progress...
# Processing page 9 of 500...
# Added 20 embeddings to the index. Total datasets processed: 177
# Saving progress...
# Processing page 10 of 500...
# Added 20 embeddings to the index. Total datasets processed: 197
# Saving progress...
# Processing page 11 of 500...
# Added 20 embeddings to the index. Total datasets processed: 217
# Saving progress...
# Processing page 12 of 500...
# Added 20 embeddings to the index. Total datasets processed: 237
# Saving progress...
# Processing page 13 of 500...
# Added 20 embeddings to the index. Total datasets processed: 257
# Saving progress...
# Processing page 14 of 500...
# Added 20 embeddings to the index. Total datasets processed: 277
# Saving progress...
# Processing page 15 of 500...
# Added 20 embeddings to the index. Total datasets processed: 297
# Saving progress...
# Processing page 16 of 500...
# Added 20 embeddings to the index. Total datasets processed: 317
# Saving progress...
# Processing page 17 of 500...
# Added 20 embeddings to the index. Total datasets processed: 337
# Saving progress...
# Processing page 18 of 500...
# Added 19 embeddings to the index. Total datasets processed: 356
# Saving progress...
# Processing page 19 of 500...
# Added 19 embeddings to the index. Total datasets processed: 375
# Saving progress...
# Processing page 20 of 500...
# Added 20 embeddings to the index. Total datasets processed: 395
# Saving progress...
# Processing page 21 of 500...
# Added 20 embeddings to the index. Total datasets processed: 415
# Saving progress...
# Processing page 22 of 500...
# Added 20 embeddings to the index. Total datasets processed: 435
# Saving progress...
# Processing page 23 of 500...
# Added 19 embeddings to the index. Total datasets processed: 454
# Saving progress...
# Processing page 24 of 500...
# Added 20 embeddings to the index. Total datasets processed: 474
# Saving progress...
# Processing page 25 of 500...
# Added 20 embeddings to the index. Total datasets processed: 494
# Saving progress...
# Processing page 26 of 500...
# Added 20 embeddings to the index. Total datasets processed: 514
# Saving progress...
# Processing page 27 of 500...
# Added 20 embeddings to the index. Total datasets processed: 534
# Saving progress...
# Processing page 28 of 500...
# Added 20 embeddings to the index. Total datasets processed: 554
# Saving progress...
# Processing page 29 of 500...
# Added 20 embeddings to the index. Total datasets processed: 574
# Saving progress...
# Processing page 30 of 500...
# Added 20 embeddings to the index. Total datasets processed: 594
# Saving progress...
# Processing page 31 of 500...
# Added 20 embeddings to the index. Total datasets processed: 614
# Saving progress...
# Processing page 32 of 500...
# Added 19 embeddings to the index. Total datasets processed: 633
# Saving progress...
# Processing page 33 of 500...
# Added 20 embeddings to the index. Total datasets processed: 653
# Saving progress...
# Processing page 34 of 500...
# Added 20 embeddings to the index. Total datasets processed: 673
# Saving progress...
# Processing page 35 of 500...
# Added 20 embeddings to the index. Total datasets processed: 693
# Saving progress...
# Processing page 36 of 500...
# Added 20 embeddings to the index. Total datasets processed: 713
# Saving progress...
# Processing page 37 of 500...
# Added 20 embeddings to the index. Total datasets processed: 733
# Saving progress...
# Processing page 38 of 500...
# Added 19 embeddings to the index. Total datasets processed: 752
# Saving progress...
# Processing page 39 of 500...
# Added 20 embeddings to the index. Total datasets processed: 772
# Saving progress...
# Processing page 40 of 500...
# Added 20 embeddings to the index. Total datasets processed: 792
# Saving progress...
# Processing page 41 of 500...
# Added 20 embeddings to the index. Total datasets processed: 812
# Saving progress...
# Processing page 42 of 500...
# Added 20 embeddings to the index. Total datasets processed: 832
# Saving progress...
# Processing page 43 of 500...
# Added 20 embeddings to the index. Total datasets processed: 852
# Saving progress...
# Processing page 44 of 500...
# Added 20 embeddings to the index. Total datasets processed: 872
# Saving progress...
# Processing page 45 of 500...
# Added 19 embeddings to the index. Total datasets processed: 891
# Saving progress...
# Processing page 46 of 500...
# Added 20 embeddings to the index. Total datasets processed: 911
# Saving progress...
# Processing page 47 of 500...
# Added 20 embeddings to the index. Total datasets processed: 931
# Saving progress...
# Processing page 48 of 500...
# Added 20 embeddings to the index. Total datasets processed: 951
# Saving progress...
# Processing page 49 of 500...
# Added 20 embeddings to the index. Total datasets processed: 971
# Saving progress...
# Processing page 50 of 500...
# Added 20 embeddings to the index. Total datasets processed: 991
# Saving progress...
# Processing page 51 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1011
# Saving progress...
# Processing page 52 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1031
# Saving progress...
# Processing page 53 of 500...
# Added 19 embeddings to the index. Total datasets processed: 1050
# Saving progress...
# Processing page 54 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1070
# Saving progress...
# Processing page 55 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1090
# Saving progress...
# Processing page 56 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1110
# Saving progress...
# Processing page 57 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1130
# Saving progress...
# Processing page 58 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1150
# Saving progress...
# Processing page 59 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1170
# Saving progress...
# Processing page 60 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1190
# Saving progress...
# Processing page 61 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1210
# Saving progress...
# Processing page 62 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1230
# Saving progress...
# Processing page 63 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1250
# Saving progress...
# Processing page 64 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1270
# Saving progress...
# Processing page 65 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1290
# Saving progress...
# Processing page 66 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1310
# Saving progress...
# Processing page 67 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1330
# Saving progress...
# Processing page 68 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1350
# Saving progress...
# Processing page 69 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1370
# Saving progress...
# Processing page 70 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1390
# Saving progress...
# Processing page 71 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1410
# Saving progress...
# Processing page 72 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1430
# Saving progress...
# Processing page 73 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1450
# Saving progress...
# Processing page 74 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1470
# Saving progress...
# Processing page 75 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1490
# Saving progress...
# Processing page 76 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1510
# Saving progress...
# Processing page 77 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1530
# Saving progress...
# Processing page 78 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1550
# Saving progress...
# Processing page 79 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1570
# Saving progress...
# Processing page 80 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1590
# Saving progress...
# Processing page 81 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1610
# Saving progress...
# Processing page 82 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1630
# Saving progress...
# Processing page 83 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1650
# Saving progress...
# Processing page 84 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1670
# Saving progress...
# Processing page 85 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1690
# Saving progress...
# Processing page 86 of 500...
# Added 19 embeddings to the index. Total datasets processed: 1709
# Saving progress...
# Processing page 87 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1729
# Saving progress...
# Processing page 88 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1749
# Saving progress...
# Processing page 89 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1769
# Saving progress...
# Processing page 90 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1789
# Saving progress...
# Processing page 91 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1809
# Saving progress...
# Processing page 92 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1829
# Saving progress...
# Processing page 93 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1849
# Saving progress...
# Processing page 94 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1869
# Saving progress...
# Processing page 95 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1889
# Saving progress...
# Processing page 96 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1909
# Saving progress...
# Processing page 97 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1929
# Saving progress...
# Processing page 98 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1949
# Saving progress...
# Processing page 99 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1969
# Saving progress...
# Processing page 100 of 500...
# Added 20 embeddings to the index. Total datasets processed: 1989
# Saving progress...
# Processing page 101 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2009
# Saving progress...
# Processing page 102 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2029
# Saving progress...
# Processing page 103 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2049
# Saving progress...
# Processing page 104 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2069
# Saving progress...
# Processing page 105 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2089
# Saving progress...
# Processing page 106 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2109
# Saving progress...
# Processing page 107 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2129
# Saving progress...
# Processing page 108 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2149
# Saving progress...
# Processing page 109 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2169
# Saving progress...
# Processing page 110 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2189
# Saving progress...
# Processing page 111 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2209
# Saving progress...
# Processing page 112 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2229
# Saving progress...
# Processing page 113 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2249
# Saving progress...
# Processing page 114 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2269
# Saving progress...
# Processing page 115 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2289
# Saving progress...
# Processing page 116 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2309
# Saving progress...
# Processing page 117 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2329
# Saving progress...
# Processing page 118 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2349
# Saving progress...
# Processing page 119 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2369
# Saving progress...
# Processing page 120 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2389
# Saving progress...
# Processing page 121 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2409
# Saving progress...
# Processing page 122 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2429
# Saving progress...
# Processing page 123 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2449
# Saving progress...
# Processing page 124 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2469
# Saving progress...
# Processing page 125 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2489
# Saving progress...
# Processing page 126 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2509
# Saving progress...
# Processing page 127 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2529
# Saving progress...
# Processing page 128 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2549
# Saving progress...
# Processing page 129 of 500...
# Added 19 embeddings to the index. Total datasets processed: 2568
# Saving progress...
# Processing page 130 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2588
# Saving progress...
# Processing page 131 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2608
# Saving progress...
# Processing page 132 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2628
# Saving progress...
# Processing page 133 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2648
# Saving progress...
# Processing page 134 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2668
# Saving progress...
# Processing page 135 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2688
# Saving progress...
# Processing page 136 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2708
# Saving progress...
# Processing page 137 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2728
# Saving progress...
# Processing page 138 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2748
# Saving progress...
# Processing page 139 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2768
# Saving progress...
# Processing page 140 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2788
# Saving progress...
# Processing page 141 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2808
# Saving progress...
# Processing page 142 of 500...
# Added 19 embeddings to the index. Total datasets processed: 2827
# Saving progress...
# Processing page 143 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2847
# Saving progress...
# Processing page 144 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2867
# Saving progress...
# Processing page 145 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2887
# Saving progress...
# Processing page 146 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2907
# Saving progress...
# Processing page 147 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2927
# Saving progress...
# Processing page 148 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2947
# Saving progress...
# Processing page 149 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2967
# Saving progress...
# Processing page 150 of 500...
# Added 20 embeddings to the index. Total datasets processed: 2987
# Saving progress...
# Processing page 151 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3007
# Saving progress...
# Processing page 152 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3027
# Saving progress...
# Processing page 153 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3047
# Saving progress...
# Processing page 154 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3067
# Saving progress...
# Processing page 155 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3087
# Saving progress...
# Processing page 156 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3107
# Saving progress...
# Processing page 157 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3127
# Saving progress...
# Processing page 158 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3147
# Saving progress...
# Processing page 159 of 500...
# Added 19 embeddings to the index. Total datasets processed: 3166
# Saving progress...
# Processing page 160 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3186
# Saving progress...
# Processing page 161 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3206
# Saving progress...
# Processing page 162 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3226
# Saving progress...
# Processing page 163 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3246
# Saving progress...
# Processing page 164 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3266
# Saving progress...
# Processing page 165 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3286
# Saving progress...
# Processing page 166 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3306
# Saving progress...
# Processing page 167 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3326
# Saving progress...
# Processing page 168 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3346
# Saving progress...
# Processing page 169 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3366
# Saving progress...
# Processing page 170 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3386
# Saving progress...
# Processing page 171 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3406
# Saving progress...
# Processing page 172 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3426
# Saving progress...
# Processing page 173 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3446
# Saving progress...
# Processing page 174 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3466
# Saving progress...
# Processing page 175 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3486
# Saving progress...
# Processing page 176 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3506
# Saving progress...
# Processing page 177 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3526
# Saving progress...
# Processing page 178 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3546
# Saving progress...
# Processing page 179 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3566
# Saving progress...
# Processing page 180 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3586
# Saving progress...
# Processing page 181 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3606
# Saving progress...
# Processing page 182 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3626
# Saving progress...
# Processing page 183 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3646
# Saving progress...
# Processing page 184 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3666
# Saving progress...
# Processing page 185 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3686
# Saving progress...
# Processing page 186 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3706
# Saving progress...
# Processing page 187 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3726
# Saving progress...
# Processing page 188 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3746
# Saving progress...
# Processing page 189 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3766
# Saving progress...
# Processing page 190 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3786
# Saving progress...
# Processing page 191 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3806
# Saving progress...
# Processing page 192 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3826
# Saving progress...
# Processing page 193 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3846
# Saving progress...
# Processing page 194 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3866
# Saving progress...
# Processing page 195 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3886
# Saving progress...
# Processing page 196 of 500...
# Added 19 embeddings to the index. Total datasets processed: 3905
# Saving progress...
# Processing page 197 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3925
# Saving progress...
# Processing page 198 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3945
# Saving progress...
# Processing page 199 of 500...
# Added 20 embeddings to the index. Total datasets processed: 3965
# Saving progress...
# Processing page 200 of 500...
# Added 19 embeddings to the index. Total datasets processed: 3984
# Saving progress...
# Processing page 201 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4004
# Saving progress...
# Processing page 202 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4024
# Saving progress...
# Processing page 203 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4044
# Saving progress...
# Processing page 204 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4064
# Saving progress...
# Processing page 205 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4084
# Saving progress...
# Processing page 206 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4104
# Saving progress...
# Processing page 207 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4124
# Saving progress...
# Processing page 208 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4144
# Saving progress...
# Processing page 209 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4164
# Saving progress...
# Processing page 210 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4184
# Saving progress...
# Processing page 211 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4204
# Saving progress...
# Processing page 212 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4224
# Saving progress...
# Processing page 213 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4244
# Saving progress...
# Processing page 214 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4264
# Saving progress...
# Processing page 215 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4284
# Saving progress...
# Processing page 216 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4304
# Saving progress...
# Processing page 217 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4324
# Saving progress...
# Processing page 218 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4344
# Saving progress...
# Processing page 219 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4364
# Saving progress...
# Processing page 220 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4384
# Saving progress...
# Processing page 221 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4404
# Saving progress...
# Processing page 222 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4424
# Saving progress...
# Processing page 223 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4444
# Saving progress...
# Processing page 224 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4464
# Saving progress...
# Processing page 225 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4484
# Saving progress...
# Processing page 226 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4504
# Saving progress...
# Processing page 227 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4524
# Saving progress...
# Processing page 228 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4544
# Saving progress...
# Processing page 229 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4564
# Saving progress...
# Processing page 230 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4584
# Saving progress...
# Processing page 231 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4604
# Saving progress...
# Processing page 232 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4624
# Saving progress...
# Processing page 233 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4644
# Saving progress...
# Processing page 234 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4664
# Saving progress...
# Processing page 235 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4684
# Saving progress...
# Processing page 236 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4704
# Saving progress...
# Processing page 237 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4724
# Saving progress...
# Processing page 238 of 500...
# Added 19 embeddings to the index. Total datasets processed: 4743
# Saving progress...
# Processing page 239 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4763
# Saving progress...
# Processing page 240 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4783
# Saving progress...
# Processing page 241 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4803
# Saving progress...
# Processing page 242 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4823
# Saving progress...
# Processing page 243 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4843
# Saving progress...
# Processing page 244 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4863
# Saving progress...
# Processing page 245 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4883
# Saving progress...
# Processing page 246 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4903
# Saving progress...
# Processing page 247 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4923
# Saving progress...
# Processing page 248 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4943
# Saving progress...
# Processing page 249 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4963
# Saving progress...
# Processing page 250 of 500...
# Added 20 embeddings to the index. Total datasets processed: 4983
# Saving progress...
# Processing page 251 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5003
# Saving progress...
# Processing page 252 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5023
# Saving progress...
# Processing page 253 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5043
# Saving progress...
# Processing page 254 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5063
# Saving progress...
# Processing page 255 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5083
# Saving progress...
# Processing page 256 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5103
# Saving progress...
# Processing page 257 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5123
# Saving progress...
# Processing page 258 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5143
# Saving progress...
# Processing page 259 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5163
# Saving progress...
# Processing page 260 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5183
# Saving progress...
# Processing page 261 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5203
# Saving progress...
# Processing page 262 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5223
# Saving progress...
# Processing page 263 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5243
# Saving progress...
# Processing page 264 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5263
# Saving progress...
# Processing page 265 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5283
# Saving progress...
# Processing page 266 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5303
# Saving progress...
# Processing page 267 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5323
# Saving progress...
# Processing page 268 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5343
# Saving progress...
# Processing page 269 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5363
# Saving progress...
# Processing page 270 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5383
# Saving progress...
# Processing page 271 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5403
# Saving progress...
# Processing page 272 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5423
# Saving progress...
# Processing page 273 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5443
# Saving progress...
# Processing page 274 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5463
# Saving progress...
# Processing page 275 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5483
# Saving progress...
# Processing page 276 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5503
# Saving progress...
# Processing page 277 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5523
# Saving progress...
# Processing page 278 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5543
# Saving progress...
# Processing page 279 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5563
# Saving progress...
# Processing page 280 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5583
# Saving progress...
# Processing page 281 of 500...
# Added 19 embeddings to the index. Total datasets processed: 5602
# Saving progress...
# Processing page 282 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5622
# Saving progress...
# Processing page 283 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5642
# Saving progress...
# Processing page 284 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5662
# Saving progress...
# Processing page 285 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5682
# Saving progress...
# Processing page 286 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5702
# Saving progress...
# Processing page 287 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5722
# Saving progress...
# Processing page 288 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5742
# Saving progress...
# Processing page 289 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5762
# Saving progress...
# Processing page 290 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5782
# Saving progress...
# Processing page 291 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5802
# Saving progress...
# Processing page 292 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5822
# Saving progress...
# Processing page 293 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5842
# Saving progress...
# Processing page 294 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5862
# Saving progress...
# Processing page 295 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5882
# Saving progress...
# Processing page 296 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5902
# Saving progress...
# Processing page 297 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5922
# Saving progress...
# Processing page 298 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5942
# Saving progress...
# Processing page 299 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5962
# Saving progress...
# Processing page 300 of 500...
# Added 20 embeddings to the index. Total datasets processed: 5982
# Saving progress...
# Processing page 301 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6002
# Saving progress...
# Processing page 302 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6022
# Saving progress...
# Processing page 303 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6042
# Saving progress...
# Processing page 304 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6062
# Saving progress...
# Processing page 305 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6082
# Saving progress...
# Processing page 306 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6102
# Saving progress...
# Processing page 307 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6122
# Saving progress...
# Processing page 308 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6142
# Saving progress...
# Processing page 309 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6162
# Saving progress...
# Processing page 310 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6182
# Saving progress...
# Processing page 311 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6202
# Saving progress...
# Processing page 312 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6222
# Saving progress...
# Processing page 313 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6242
# Saving progress...
# Processing page 314 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6262
# Saving progress...
# Processing page 315 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6282
# Saving progress...
# Processing page 316 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6302
# Saving progress...
# Processing page 317 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6322
# Saving progress...
# Processing page 318 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6342
# Saving progress...
# Processing page 319 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6362
# Saving progress...
# Processing page 320 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6382
# Saving progress...
# Processing page 321 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6402
# Saving progress...
# Processing page 322 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6422
# Saving progress...
# Processing page 323 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6442
# Saving progress...
# Processing page 324 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6462
# Saving progress...
# Processing page 325 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6482
# Saving progress...
# Processing page 326 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6502
# Saving progress...
# Processing page 327 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6522
# Saving progress...
# Processing page 328 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6542
# Saving progress...
# Processing page 329 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6562
# Saving progress...
# Processing page 330 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6582
# Saving progress...
# Processing page 331 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6602
# Saving progress...
# Processing page 332 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6622
# Saving progress...
# Processing page 333 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6642
# Saving progress...
# Processing page 334 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6662
# Saving progress...
# Processing page 335 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6682
# Saving progress...
# Processing page 336 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6702
# Saving progress...
# Processing page 337 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6722
# Saving progress...
# Processing page 338 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6742
# Saving progress...
# Processing page 339 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6762
# Saving progress...
# Processing page 340 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6782
# Saving progress...
# Processing page 341 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6802
# Saving progress...
# Processing page 342 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6822
# Saving progress...
# Processing page 343 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6842
# Saving progress...
# Processing page 344 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6862
# Saving progress...
# Processing page 345 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6882
# Saving progress...
# Processing page 346 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6902
# Saving progress...
# Processing page 347 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6922
# Saving progress...
# Processing page 348 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6942
# Saving progress...
# Processing page 349 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6962
# Saving progress...
# Processing page 350 of 500...
# Added 20 embeddings to the index. Total datasets processed: 6982
# Saving progress...
# Processing page 351 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7002
# Saving progress...
# Processing page 352 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7022
# Saving progress...
# Processing page 353 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7042
# Saving progress...
# Processing page 354 of 500...
# Added 19 embeddings to the index. Total datasets processed: 7061
# Saving progress...
# Processing page 355 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7081
# Saving progress...
# Processing page 356 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7101
# Saving progress...
# Processing page 357 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7121
# Saving progress...
# Processing page 358 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7141
# Saving progress...
# Processing page 359 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7161
# Saving progress...
# Processing page 360 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7181
# Saving progress...
# Processing page 361 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7201
# Saving progress...
# Processing page 362 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7221
# Saving progress...
# Processing page 363 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7241
# Saving progress...
# Processing page 364 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7261
# Saving progress...
# Processing page 365 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7281
# Saving progress...
# Processing page 366 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7301
# Saving progress...
# Processing page 367 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7321
# Saving progress...
# Processing page 368 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7341
# Saving progress...
# Processing page 369 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7361
# Saving progress...
# Processing page 370 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7381
# Saving progress...
# Processing page 371 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7401
# Saving progress...
# Processing page 372 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7421
# Saving progress...
# Processing page 373 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7441
# Saving progress...
# Processing page 374 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7461
# Saving progress...
# Processing page 375 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7481
# Saving progress...
# Processing page 376 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7501
# Saving progress...
# Processing page 377 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7521
# Saving progress...
# Processing page 378 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7541
# Saving progress...
# Processing page 379 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7561
# Saving progress...
# Processing page 380 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7581
# Saving progress...
# Processing page 381 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7601
# Saving progress...
# Processing page 382 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7621
# Saving progress...
# Processing page 383 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7641
# Saving progress...
# Processing page 384 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7661
# Saving progress...
# Processing page 385 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7681
# Saving progress...
# Processing page 386 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7701
# Saving progress...
# Processing page 387 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7721
# Saving progress...
# Processing page 388 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7741
# Saving progress...
# Processing page 389 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7761
# Saving progress...
# Processing page 390 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7781
# Saving progress...
# Processing page 391 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7801
# Saving progress...
# Processing page 392 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7821
# Saving progress...
# Processing page 393 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7841
# Saving progress...
# Processing page 394 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7861
# Saving progress...
# Processing page 395 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7881
# Saving progress...
# Processing page 396 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7901
# Saving progress...
# Processing page 397 of 500...
# Added 19 embeddings to the index. Total datasets processed: 7920
# Saving progress...
# Processing page 398 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7940
# Saving progress...
# Processing page 399 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7960
# Saving progress...
# Processing page 400 of 500...
# Added 20 embeddings to the index. Total datasets processed: 7980
# Saving progress...
# Processing page 401 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8000
# Saving progress...
# Processing page 402 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8020
# Saving progress...
# Processing page 403 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8040
# Saving progress...
# Processing page 404 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8060
# Saving progress...
# Processing page 405 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8080
# Saving progress...
# Processing page 406 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8100
# Saving progress...
# Processing page 407 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8120
# Saving progress...
# Processing page 408 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8140
# Saving progress...
# Processing page 409 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8160
# Saving progress...
# Processing page 410 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8180
# Saving progress...
# Processing page 411 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8200
# Saving progress...
# Processing page 412 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8220
# Saving progress...
# Processing page 413 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8240
# Saving progress...
# Processing page 414 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8260
# Saving progress...
# Processing page 415 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8280
# Saving progress...
# Processing page 416 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8300
# Saving progress...
# Processing page 417 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8320
# Saving progress...
# Processing page 418 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8340
# Saving progress...
# Processing page 419 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8360
# Saving progress...
# Processing page 420 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8380
# Saving progress...
# Processing page 421 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8400
# Saving progress...
# Processing page 422 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8420
# Saving progress...
# Processing page 423 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8440
# Saving progress...
# Processing page 424 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8460
# Saving progress...
# Processing page 425 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8480
# Saving progress...
# Processing page 426 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8500
# Saving progress...
# Processing page 427 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8520
# Saving progress...
# Processing page 428 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8540
# Saving progress...
# Processing page 429 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8560
# Saving progress...
# Processing page 430 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8580
# Saving progress...
# Processing page 431 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8600
# Saving progress...
# Processing page 432 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8620
# Saving progress...
# Processing page 433 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8640
# Saving progress...
# Processing page 434 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8660
# Saving progress...
# Processing page 435 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8680
# Saving progress...
# Processing page 436 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8700
# Saving progress...
# Processing page 437 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8720
# Saving progress...
# Processing page 438 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8740
# Saving progress...
# Processing page 439 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8760
# Saving progress...
# Processing page 440 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8780
# Saving progress...
# Processing page 441 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8800
# Saving progress...
# Processing page 442 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8820
# Saving progress...
# Processing page 443 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8840
# Saving progress...
# Processing page 444 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8860
# Saving progress...
# Processing page 445 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8880
# Saving progress...
# Processing page 446 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8900
# Saving progress...
# Processing page 447 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8920
# Saving progress...
# Processing page 448 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8940
# Saving progress...
# Processing page 449 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8960
# Saving progress...
# Processing page 450 of 500...
# Added 20 embeddings to the index. Total datasets processed: 8980
# Saving progress...
# Processing page 451 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9000
# Saving progress...
# Processing page 452 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9020
# Saving progress...
# Processing page 453 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9040
# Saving progress...
# Processing page 454 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9060
# Saving progress...
# Processing page 455 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9080
# Saving progress...
# Processing page 456 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9100
# Saving progress...
# Processing page 457 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9120
# Saving progress...
# Processing page 458 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9140
# Saving progress...
# Processing page 459 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9160
# Saving progress...
# Processing page 460 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9180
# Saving progress...
# Processing page 461 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9200
# Saving progress...
# Processing page 462 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9220
# Saving progress...
# Processing page 463 of 500...
# Added 19 embeddings to the index. Total datasets processed: 9239
# Saving progress...
# Processing page 464 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9259
# Saving progress...
# Processing page 465 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9279
# Saving progress...
# Processing page 466 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9299
# Saving progress...
# Processing page 467 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9319
# Saving progress...
# Processing page 468 of 500...
# Added 19 embeddings to the index. Total datasets processed: 9338
# Saving progress...
# Processing page 469 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9358
# Saving progress...
# Processing page 470 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9378
# Saving progress...
# Processing page 471 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9398
# Saving progress...
# Processing page 472 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9418
# Saving progress...
# Processing page 473 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9438
# Saving progress...
# Processing page 474 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9458
# Saving progress...
# Processing page 475 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9478
# Saving progress...
# Processing page 476 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9498
# Saving progress...
# Processing page 477 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9518
# Saving progress...
# Processing page 478 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9538
# Saving progress...
# Processing page 479 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9558
# Saving progress...
# Processing page 480 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9578
# Saving progress...
# Processing page 481 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9598
# Saving progress...
# Processing page 482 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9618
# Saving progress...
# Processing page 483 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9638
# Saving progress...
# Processing page 484 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9658
# Saving progress...
# Processing page 485 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9678
# Saving progress...
# Processing page 486 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9698
# Saving progress...
# Processing page 487 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9718
# Saving progress...
# Processing page 488 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9738
# Saving progress...
# Processing page 489 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9758
# Saving progress...
# Processing page 490 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9778
# Saving progress...
# Processing page 491 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9798
# Saving progress...
# Processing page 492 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9818
# Saving progress...
# Processing page 493 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9838
# Saving progress...
# Processing page 494 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9858
# Saving progress...
# Processing page 495 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9878
# Saving progress...
# Processing page 496 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9898
# Saving progress...
# Processing page 497 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9918
# Saving progress...
# Processing page 498 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9938
# Saving progress...
# Processing page 499 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9958
# Saving progress...
# Processing page 500 of 500...
# Added 20 embeddings to the index. Total datasets processed: 9978
# Saving progress...
# Finished processing 9978 datasets.

# %%
# Load the FAISS index
index_path = 'kaggle_embeddings.index'  # Adjust this path if necessary
loaded_index = faiss.read_index(index_path)

# Check the number of datapoints in the index
num_datapoints = loaded_index.ntotal

print(f"The FAISS index contains {num_datapoints} datapoints.")
# Out:
# The FAISS index contains 9978 datapoints.

# %% [markdown]
# ## test of query

# %%
import pandas as pd
import zipfile

def find_similar_datasets(query: str, index: faiss.Index, dataset_info: List[Dict], k: int = 5) -> List[Dict]:
    query_embedding = get_embedding(query)
    
    # Convert query embedding to numpy array
    query_array = np.array([query_embedding]).astype('float32')
    
    # Perform similarity search
    distances, indices = index.search(query_array, k)
    
    return [dataset_info[i] for i in indices[0]]


def find_and_prepare_kaggle_dataset(treatment: str, outcome: str, dag_variables: List[str], index: faiss.Index, dataset_info: List[Dict]) -> pd.DataFrame:
    query = f"Dataset for analyzing the effect of {treatment} on {outcome}, considering variables: {', '.join(dag_variables)}"
    
    similar_datasets = find_similar_datasets(query, index, dataset_info)
    
    print("Top 5 similar datasets:")
    for i, dataset in enumerate(similar_datasets, 1):
        print(f"{i}. {dataset['ref']}: {dataset['title']}")
        print(f"   Description: {dataset['description'][:100]}...")  # Show first 100 characters of description
    
    while True:
        try:
            choice = int(input("\nChoose a dataset (1-5) or 0 to cancel: "))
            if 0 <= choice <= 5:
                break
            else:
                print("Please enter a number between 0 and 5.")
        except ValueError:
            print("Please enter a valid number.")
    
    if choice == 0:
        print("Operation cancelled by the user.")
        return None
    
    selected_dataset = similar_datasets[choice - 1]
    dataset_ref = selected_dataset['ref']
    
    print(f"\nSelected dataset: {dataset_ref}")
    print(f"Dataset description: {selected_dataset['description']}")
    
    print("Proceeding with dataset download and processing...")

    api.dataset_download_files(dataset_ref)
    
    dataset_name = dataset_ref.split("/")[-1]
    
    with zipfile.ZipFile(f"{dataset_name}.zip", "r") as zip_ref:
        zip_ref.extractall(dataset_name)
    
    df = pd.read_csv(f"{dataset_name}/data.csv")
    
    variable_mapping = map_variables(dag_variables, df.columns.tolist())
    
    relevant_columns = [col for col in variable_mapping.values() if col != 'None']
    df_filtered = df[relevant_columns]
    
    rename_dict = {v: k for k, v in variable_mapping.items() if v != 'None'}
    df_renamed = df_filtered.rename(columns=rename_dict)
    
    return df_renamed


# Test the find_and_prepare_kaggle_dataset function

# Load the dataset info
with open('kaggle_embeddings_info.pkl', 'rb') as f:
    dataset_info = pickle.load(f)

# Define test parameters
treatment = "danceability"
outcome = "liked"
dag_variables = ["energy", "loudness", "tempo", "valence"]

# Call the function
df_result = find_and_prepare_kaggle_dataset(treatment, outcome, dag_variables, loaded_index, dataset_info)

# Display the first few rows and basic information about the resulting dataframe
print(df_result.head())
print("\nDataframe info:")
print(df_result.info())

# Check if all specified variables are present in the result
all_variables = [treatment, outcome] + dag_variables
missing_variables = [var for var in all_variables if var not in df_result.columns]

if missing_variables:
    print(f"\nWarning: The following variables are missing from the result: {', '.join(missing_variables)}")
else:
    print("\nAll specified variables are present in the result.")
# Out:
# Top 5 similar datasets:
# 1. yasaminjafarian/tiktokdataset: TikTokDataset
#    Description: ...
# 2. imsparsh/deam-mediaeval-dataset-emotional-analysis-in-music: DEAM Dataset - Emotional Analysis in Music
#    Description: ...
# 3. meeraajayakumar/spotify-user-behavior-dataset: Spotify User Behavior Dataset
#    Description: ...
# 4. mahdiehhajian/women-clothes: women clothes👗🥻
#    Description: ...
# 5. uldisvalainis/audio-emotions: Audio emotions
#    Description: ...
#
# Selected dataset: meeraajayakumar/spotify-user-behavior-dataset
# Dataset description:
# Proceeding with dataset download and processing...
# Dataset URL: https://www.kaggle.com/datasets/meeraajayakumar/spotify-user-behavior-dataset
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 79
#      76 dag_variables = ["energy", "loudness", "tempo", "valence"]
#      78 # Call the function
# ---> 79 df_result = find_and_prepare_kaggle_dataset(treatment, outcome, dag_variables, loaded_index, dataset_info)
#      81 # Display the first few rows and basic information about the resulting dataframe
#      82 print(df_result.head())
#
# Cell In[12], line 51, in find_and_prepare_kaggle_dataset(treatment, outcome, dag_variables, index, dataset_info)
#      47 api.dataset_download_files(dataset_ref)
#      49 dataset_name = dataset_ref.split("/")[-1]
# ---> 51 with zipfile.ZipFile(f"{dataset_name}.zip", "r") as zip_ref:
#      52     zip_ref.extractall(dataset_name)
#      54 df = pd.read_csv(f"{dataset_name}/data.csv")
#
# NameError: name 'zipfile' is not defined
